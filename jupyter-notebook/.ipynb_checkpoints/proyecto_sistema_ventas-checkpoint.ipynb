# %% [markdown]
# #### ORM SQLALCHEMY - CREAR EL DIAGRAMA ER

# %% [markdown]
# #### Instalando la dependencias

# %%
# !pip install SQLAlchemy
# !pip install numpy
# !pip install pandas
# !pip install pymysql
# !pip install matplotlib
# !pip install openpyxl
# Out:
# Requirement already satisfied: SQLAlchemy in /opt/conda/lib/python3.11/site-packages (2.0.22)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy) (3.0.0)
# Collecting numpy
#   Downloading numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 48.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-2.0.0
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 59.1 MB/s eta 0:00:00:00:0100:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2024.1
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 426.3 kB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 49.1 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 9.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 50.5 MB/s eta 0:00:00:00:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.8 MB/s eta 0:00:00:00:01
# Downloading pillow-10.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 47.1 MB/s eta 0:00:00:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 4.8 MB/s eta 0:00:00:00:01
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5

# %%
from sqlalchemy import Column, Integer, String, Float, Date, SmallInteger, ForeignKey
from sqlalchemy.orm import declarative_base
from sqlalchemy import create_engine
from sqlalchemy import select

# %%
engine = create_engine('mysql+pymysql://root:Changeme123@mysql-container:3306/datapath', echo="debug")

# %%
Base = declarative_base()

# %%
class Pedido(Base):
    __tablename__ = "pedido"
    __table_args__ = { 'extend_existing': True }
    id_pedido = Column(Integer, primary_key=True, autoincrement=True)
    uuid_pedido = Column(String(50), primary_key=True, unique=True)
    estado = Column(String(20))
    region = Column(String(255))
    categoria = Column(String(255))
    cantidad = Column(Integer)
    descuento = Column(Float(3,2))

# %%
class Cliente(Base):
    __tablename__ = "cliente"
    __table_args__ = { 'extend_existing': True }
    id_cliente = Column(Integer, primary_key=True, autoincrement=True)
    uuid_cliente = Column(String(50), primary_key=True, unique=True)
    nombre_cliente = Column(String(255))
    edad = Column(Integer)
    # telefono = Column(BigInteger)
    # direccion = Column(String(500))
    genero = Column(String(10))

# %%
class Producto(Base):
    __tablename__ = "producto"
    __table_args__ = { 'extend_existing': True }
    id_producto = Column(Integer, primary_key=True, autoincrement=True)
    uuid_producto = Column(String(50),primary_key=True, unique=True)
    nombre_producto = Column(String(255))
    precio = Column(Float(10,2))
    igv = Column(Float(10,2))

# %%
class Fecha(Base):
    __table_args__ = { 'extend_existing': True }
    __tablename__ = "fecha"
    id_fecha = Column(Integer, primary_key=True, autoincrement=True)
    uuid_fecha = Column(String(50), primary_key=True, unique=True)
    fec_pedido = Column(Date)
    fec_prime = Column(Date)
    fec_vto = Column(Date)
    fec_mora = Column(Date)
    anio = Column(Integer)
    mes = Column(Integer)
    dia = Column(Integer)
    mes_nombre = Column(String(50))
    trimestre = Column(SmallInteger)
    semestre = Column(SmallInteger)

# %%
class SistemaVentas(Base):
    __table_args__ = { 'extend_existing': True }
    __tablename__ = "sistema_ventas"
    id_venta = Column(Integer, primary_key=True, autoincrement=True)
    cliente_id_cliente = Column(String(50), ForeignKey("cliente.uuid_cliente"), nullable=False)
    pedido_id_pedido = Column(String(50), ForeignKey("pedido.uuid_pedido"), nullable=False)
    fecha_id_fecha = Column(String(50), ForeignKey("fecha.uuid_fecha"), nullable=False)
    producto_id_producto = Column(String(50), ForeignKey("producto.uuid_producto") ,nullable=False)

# %%
# crear los modelos en la base de datos
Base.metadata.create_all(engine)
# Out:
# 2024-06-30 22:49:06,614 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-06-30 22:49:06,614 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,615 DEBUG sqlalchemy.engine.Engine Col ('DATABASE()',)
# 2024-06-30 22:49:06,616 DEBUG sqlalchemy.engine.Engine Row ('datapath',)
# 2024-06-30 22:49:06,617 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-06-30 22:49:06,618 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,619 DEBUG sqlalchemy.engine.Engine Col ('@@sql_mode',)
# 2024-06-30 22:49:06,619 DEBUG sqlalchemy.engine.Engine Row ('ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION',)
# 2024-06-30 22:49:06,620 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-06-30 22:49:06,621 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,622 DEBUG sqlalchemy.engine.Engine Col ('@@lower_case_table_names',)
# 2024-06-30 22:49:06,622 DEBUG sqlalchemy.engine.Engine Row (0,)
# 2024-06-30 22:49:06,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 22:49:06,624 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`pedido`
# 2024-06-30 22:49:06,625 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,629 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:49:06,630 DEBUG sqlalchemy.engine.Engine Row ('id_pedido', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:49:06,631 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`cliente`
# 2024-06-30 22:49:06,632 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,633 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:49:06,634 DEBUG sqlalchemy.engine.Engine Row ('id_cliente', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:49:06,635 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`producto`
# 2024-06-30 22:49:06,635 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,637 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:49:06,638 DEBUG sqlalchemy.engine.Engine Row ('id_producto', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:49:06,638 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`fecha`
# 2024-06-30 22:49:06,639 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,641 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:49:06,641 DEBUG sqlalchemy.engine.Engine Row ('id_fecha', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:49:06,642 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`sistema_ventas`
# 2024-06-30 22:49:06,642 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:49:06,644 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:49:06,644 DEBUG sqlalchemy.engine.Engine Row ('id_venta', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:49:06,645 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### CARGA DE DATOS A LA BASE DE DATOS OLAP

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import logging
import uuid
import sys
import os

# %%
fecha_ejecucion = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Hora de ejecucion { fecha_ejecucion }")
# Out:
# Hora de ejecucion 2024-06-30 22:50:01

# %%
# CARGANDO LOS DATOS DEL XLSX
dataset = os.getcwd()+"/DATA_PEDIDOS.xlsx"
if not os.path.isfile(dataset):
    logging.warning(f"Not found path: { dataset }")
    sys.exit(3)

# %%
df = pd.read_excel(dataset, header=0, date_format=True)
df.head()
# Out:
#      ID  FECPEDIDO   FECPRIME     FECVTO    FECMORA  ANIO  MES  DIA MESNOMBRE  \
# 0  4203 2017-01-01 2013-01-06 2017-01-11 2017-01-12  2017    1    1     Enero
# 1  4203 2017-02-12 2013-01-06 2017-02-22 2017-02-23  2017    2   12   Febrero
# 2  4203 2017-03-10 2013-01-06 2017-03-20 2017-03-21  2017    3   10     Marzo
# 3  4203 2017-04-10 2013-01-06 2017-04-20 2017-04-21  2017    4   10     Abril
# 4  4203 2017-05-06 2013-01-06 2017-05-16 2017-05-17  2017    5    6      Mayo
#
#    TRIMESTRE  ...  PRECIO CANT   SUBTO  DSCTO    IGV  COST  TOTVTA     ESTADO  \
# 0          1  ...    4.36  3.0   13.08    0.1   2.35  45.0   59.13  Entregado
# 1          1  ...   31.52  8.0  252.16    0.1  45.39  55.0  327.33  Entregado
# 2          1  ...   96.64  2.0  193.28    0.1  34.79  55.0  263.74  Entregado
# 3          2  ...    8.86  4.0   35.44    0.1   6.38  55.0   93.28  Entregado
# 4          2  ...   35.80  2.0   71.60    0.1  12.89  55.0  132.33  Entregado
#
#   TIPVTA FECFACTURA
# 0    NaN        NaN
# 1    NaN        NaN
# 2    NaN        NaN
# 3    NaN        NaN
# 4    NaN        NaN
#
# [5 rows x 30 columns]

# %%
# Trabajamos con una copia de dataframe en caso necesitemos realizar Rollback en algún procedimiento ejecutado
df_copy = df.copy()

# %%
df_copy.columns
# Out:
# Index(['ID', 'FECPEDIDO', 'FECPRIME', 'FECVTO', 'FECMORA', 'ANIO', 'MES',
#        'DIA', 'MESNOMBRE', 'TRIMESTRE', 'SEMESTRE', 'NOMCLI', 'SEX', 'EDAD',
#        'TELE', 'DIR', 'EMAIL', 'REGION', 'CATE', 'NOMPRO', 'PRECIO', 'CANT',
#        'SUBTO', 'DSCTO', 'IGV', 'COST', 'TOTVTA', 'ESTADO', 'TIPVTA',
#        'FECFACTURA'],
#       dtype='object')

# %%
f"Dimension de la matriz df_copy: { df.shape }"
# Out:
# 'Dimension de la matriz df_copy: (15000, 30)'

# %%
# Validando vacios dentro del dataframe
df_copy.isna().sum()
# Out:
# ID                0
# FECPEDIDO         0
# FECPRIME          0
# FECVTO            0
# FECMORA           0
# ANIO              0
# MES               0
# DIA               0
# MESNOMBRE         0
# TRIMESTRE         0
# SEMESTRE          0
# NOMCLI            0
# SEX               0
# EDAD              0
# TELE          14713
# DIR           14734
# EMAIL             0
# REGION            0
# CATE              0
# NOMPRO            0
# PRECIO            1
# CANT              1
# SUBTO             0
# DSCTO             0
# IGV               0
# COST              0
# TOTVTA            0
# ESTADO            0
# TIPVTA        15000
# FECFACTURA    15000
# dtype: int64

# %% [markdown]
# ###### ELIMINAR LAS COLUMNAS LAS CUALES NO NOS SIRVE PARA EL PROCESAMIENTO DE LOS DATOS YA QUE NO TIENEN VALORES EN LA MAYORIA DE CASOS

# %%
df_copy = df_copy.drop(['TELE', 'DIR', 'TIPVTA', 'FECFACTURA'], axis=1)
df_copy.columns
# Out:
# Index(['ID', 'FECPEDIDO', 'FECPRIME', 'FECVTO', 'FECMORA', 'ANIO', 'MES',
#        'DIA', 'MESNOMBRE', 'TRIMESTRE', 'SEMESTRE', 'NOMCLI', 'SEX', 'EDAD',
#        'EMAIL', 'REGION', 'CATE', 'NOMPRO', 'PRECIO', 'CANT', 'SUBTO', 'DSCTO',
#        'IGV', 'COST', 'TOTVTA', 'ESTADO'],
#       dtype='object')

# %% [markdown]
# ###### ANALIZANDO LA COLUMNA EDAD REFERENTE A LOS CLIENTES
# ###### Se valida que no tiene coincidencia la edad del cliente con la fecha

# %%
df_copy[['NOMCLI', 'EDAD','ANIO']].head()
# Out:
#           NOMCLI  EDAD  ANIO
# 0  Aaron Bergman    49  2017
# 1  Aaron Bergman    60  2017
# 2  Aaron Bergman    60  2017
# 3  Aaron Bergman    60  2017
# 4  Aaron Bergman    60  2017

# %%
df_copy['NOMCLI'].value_counts()
# Out:
# NOMCLI
# Bruce Stewart          66
# Brosina Hoffman        64
# Chloris Kastensmidt    64
# Christina DeMoss       62
# Cindy Chapman          61
#                        ..
# Candace McMahon        19
# Lela Donovan           19
# Sung Shariari          18
# Carlos Meador          16
# Darren Budd            15
# Name: count, Length: 399, dtype: int64

# %%
# plotear la edad en funcion del tiempo
def _grafico_cliente_fecha(nom_cliente):
    plt.plot(df_copy[df['NOMCLI'] == nom_cliente]['FECPEDIDO'], df_copy[df['NOMCLI'] == nom_cliente]['EDAD'], 'ro')
    plt.show()

# %%
_grafico_cliente_fecha("Chloris Kastensmidt") # EDAD 180 años

# %%
# Edades que superan lo real, datos inconsistentes. Se toma como max valor 100 años
max_age = 100
df_copy[df_copy['EDAD'] > max_age]
# Out:
#           ID  FECPEDIDO   FECPRIME     FECVTO    FECMORA  ANIO  MES  DIA  \
# 142     6089 2015-11-21 2013-01-12 2015-12-01 2015-12-02  2015   11   21
# 219    11657 2014-05-02 2013-01-05 2014-05-12 2014-05-13  2014    5    2
# 220    11657 2014-06-20 2013-01-05 2014-06-30 2014-07-01  2014    6   20
# 221    11657 2014-07-02 2013-01-05 2014-07-12 2014-07-13  2014    7    2
# 227    11657 2015-01-04 2013-01-05 2015-01-14 2015-01-15  2015    1    4
# ...      ...        ...        ...        ...        ...   ...  ...  ...
# 14887  24816 2014-11-13 2012-04-12 2014-11-23 2014-11-24  2014   11   13
# 14888  24816 2014-11-13 2012-04-12 2014-11-23 2014-11-24  2014   11   13
# 14889  24816 2014-11-13 2012-04-12 2014-11-23 2014-11-24  2014   11   13
# 14890  24816 2014-11-13 2012-04-12 2014-11-23 2014-11-24  2014   11   13
# 14942  24157 2015-06-08 2012-12-08 2015-06-18 2015-06-19  2015    6    8
#
#        MESNOMBRE  TRIMESTRE  ...                 CATE  \
# 142    Noviembre          4  ...  Material de oficina
# 219         Mayo          2  ...  Material de oficina
# 220        Junio          2  ...           Tecnología
# 221        Julio          3  ...  Material de oficina
# 227        Enero          1  ...  Material de oficina
# ...          ...        ...  ...                  ...
# 14887  Noviembre          4  ...  Material de oficina
# 14888  Noviembre          4  ...  Material de oficina
# 14889  Noviembre          4  ...  Material de oficina
# 14890  Noviembre          4  ...  Material de oficina
# 14942      Junio          2  ...  Material de oficina
#
#                                                  NOMPRO  PRECIO  CANT  \
# 142                         Accos Rubber Bands, 12 Pack   10.74   5.0
# 219                      Ibico Binding Machine, Economy   34.28   7.0
# 220                     Brother Fax Machine, High-Speed  210.74   5.0
# 221                        Ibico Binder Covers, Durable   10.10   3.0
# 227            Novimex File Folder Labels, Alphabetical    5.38   2.0
# ...                                                 ...     ...   ...
# 14887                              Sanford Canvas, Blue   15.16   1.0
# 14888                    Avery Binding Machine, Economy   14.65   1.0
# 14889                   Fellowes Shelving, Single Width   17.36   1.0
# 14890  Harbour Creations File Folder Labels, Adjustable    1.99   1.0
# 14942                          Elite Trimmer, Easy Grip   43.29   6.0
#
#          SUBTO DSCTO     IGV  COST   TOTVTA     ESTADO
# 142      53.70   0.1    9.67  59.0     0.00    Anulado
# 219     239.96   0.1   43.19  60.0   319.16  Entregado
# 220    1053.70   0.1  189.67  60.0  1198.00  Entregado
# 221      30.30   0.1    5.45  60.0    92.72  Entregado
# 227      10.76   0.1    1.94  59.0    70.62  Entregado
# ...        ...   ...     ...   ...      ...        ...
# 14887    15.16   0.1    2.73  68.5    84.87  Entregado
# 14888    14.65   0.1    2.64  68.5    84.32  Entregado
# 14889    17.36   0.1    3.12  68.5    87.25  Entregado
# 14890     1.99   0.1    0.36  68.5    70.65  Entregado
# 14942   259.74   0.0   46.75  60.0   366.49  Entregado
#
# [248 rows x 26 columns]

# %%
# Lista de Clientes del dataset
clientes = df_copy['NOMCLI'].drop_duplicates().to_list()

# %%
# Eliminando la inconsistencia de registros edad mayor a 100 años
df_copy = df_copy.drop(df_copy[(df_copy.EDAD > 100)].index)

# %%
_grafico_cliente_fecha('Chloris Kastensmidt')
# Out:
# /tmp/ipykernel_865/1158746849.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(df_copy[df['NOMCLI'] == nom_cliente]['FECPEDIDO'], df_copy[df['NOMCLI'] == nom_cliente]['EDAD'], 'ro')
# /tmp/ipykernel_865/1158746849.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(df_copy[df['NOMCLI'] == nom_cliente]['FECPEDIDO'], df_copy[df['NOMCLI'] == nom_cliente]['EDAD'], 'ro')

# %%
df_copy[['NOMCLI', 'EDAD', 'FECPEDIDO']].head()
# Out:
#           NOMCLI  EDAD  FECPEDIDO
# 0  Aaron Bergman    49 2017-01-01
# 1  Aaron Bergman    60 2017-02-12
# 2  Aaron Bergman    60 2017-03-10
# 3  Aaron Bergman    60 2017-04-10
# 4  Aaron Bergman    60 2017-05-06

# %%
# Calculamos el promedio de las edades para estimar un posible valor real
df_age = df_copy[['NOMCLI', 'EDAD']]
df_age = df_age.groupby('NOMCLI', as_index=False).mean()
df_age.head()
# Out:
#             NOMCLI       EDAD
# 0    Aaron Bergman  46.166667
# 1    Aaron Hawkins  41.821429
# 2   Aaron Smayling  43.928571
# 3  Adam Bellavance  35.606061
# 4        Adam Hart  42.052632

# %%
# Transformar la Edad a un valor entero
df_age['EDAD'] = df_age['EDAD'].apply(lambda x: int(x))
df_age.head()
# Out:
#             NOMCLI  EDAD
# 0    Aaron Bergman    46
# 1    Aaron Hawkins    41
# 2   Aaron Smayling    43
# 3  Adam Bellavance    35
# 4        Adam Hart    42

# %%
# Realizando un merge para actualizar la edad en el dataframe principal
df_copy = df_copy.merge(df_age, on='NOMCLI', how='left', suffixes=('','_new'))
df_copy[['NOMCLI', 'EDAD', 'EDAD_new']].head()
# Out:
#           NOMCLI  EDAD  EDAD_new
# 0  Aaron Bergman    49        46
# 1  Aaron Bergman    60        46
# 2  Aaron Bergman    60        46
# 3  Aaron Bergman    60        46
# 4  Aaron Bergman    60        46

# %%
df_copy['EDAD'] = df_copy['EDAD_new'].combine_first(df_copy['EDAD'])
df_copy[['NOMCLI', 'EDAD']].head()
# Out:
#           NOMCLI  EDAD
# 0  Aaron Bergman    46
# 1  Aaron Bergman    46
# 2  Aaron Bergman    46
# 3  Aaron Bergman    46
# 4  Aaron Bergman    46

# %%
# Calculando el año min
df_anio_min = df_copy[['NOMCLI', 'ANIO']].groupby('NOMCLI', as_index=False).min()
df_anio_min.head()
# Out:
#             NOMCLI  ANIO
# 0    Aaron Bergman  2013
# 1    Aaron Hawkins  2014
# 2   Aaron Smayling  2014
# 3  Adam Bellavance  2013
# 4        Adam Hart  2013

# %%
# HACIENDO EL CRUCE PARA EL ANIO
df_copy = df_copy.merge(df_anio_min, how='left', on='NOMCLI', suffixes=('','_min'))
df_copy['DIFF_ANIO'] = df_copy['ANIO'] - df_copy['ANIO_min']

# %%
df_copy[['NOMCLI','ANIO', 'EDAD', 'EDAD_new', 'ANIO_min', 'DIFF_ANIO']].head()
# Out:
#           NOMCLI  ANIO  EDAD  EDAD_new  ANIO_min  DIFF_ANIO
# 0  Aaron Bergman  2017    46        46      2013          4
# 1  Aaron Bergman  2017    46        46      2013          4
# 2  Aaron Bergman  2017    46        46      2013          4
# 3  Aaron Bergman  2017    46        46      2013          4
# 4  Aaron Bergman  2017    46        46      2013          4

# %%
# Actualizando las edades
df_copy['EDAD_calculada'] = df_copy['EDAD_new']+ df_copy['DIFF_ANIO']

# %%
df_copy[['NOMCLI','ANIO', 'EDAD', 'EDAD_new', 'ANIO_min', 'DIFF_ANIO', 'EDAD_calculada']].head()
# Out:
#           NOMCLI  ANIO  EDAD  EDAD_new  ANIO_min  DIFF_ANIO  EDAD_calculada
# 0  Aaron Bergman  2017    46        46      2013          4              50
# 1  Aaron Bergman  2017    46        46      2013          4              50
# 2  Aaron Bergman  2017    46        46      2013          4              50
# 3  Aaron Bergman  2017    46        46      2013          4              50
# 4  Aaron Bergman  2017    46        46      2013          4              50

# %%
df_copy.columns
# Out:
# Index(['ID', 'FECPEDIDO', 'FECPRIME', 'FECVTO', 'FECMORA', 'ANIO', 'MES',
#        'DIA', 'MESNOMBRE', 'TRIMESTRE', 'SEMESTRE', 'NOMCLI', 'SEX', 'EDAD',
#        'EMAIL', 'REGION', 'CATE', 'NOMPRO', 'PRECIO', 'CANT', 'SUBTO', 'DSCTO',
#        'IGV', 'COST', 'TOTVTA', 'ESTADO', 'EDAD_new', 'ANIO_min', 'DIFF_ANIO',
#        'EDAD_calculada'],
#       dtype='object')

# %%
# CREANDO EL DATAFRAME DE CLIENTES
df_cliente = df_copy[['NOMCLI', 'EDAD_calculada', 'SEX']]
df_cliente['uuid'] = [uuid.uuid4() for _ in range(len(df_cliente.index))]
# Out:
# /tmp/ipykernel_865/906541885.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cliente['uuid'] = [uuid.uuid4() for _ in range(len(df_cliente.index))]

# %%
df_cliente.head()
# Out:
#           NOMCLI  EDAD_calculada        SEX  \
# 0  Aaron Bergman              50  Masculino
# 1  Aaron Bergman              50  Masculino
# 2  Aaron Bergman              50  Masculino
# 3  Aaron Bergman              50  Masculino
# 4  Aaron Bergman              50  Masculino
#
#                                    uuid
# 0  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f
# 1  031fe653-fed6-4f09-803c-82f7e5290e5b
# 2  c43e77ce-628b-43eb-9fac-75f24dd1e661
# 3  88991106-d43a-4ca0-9f54-d0d64e66762e
# 4  9d7bbd67-9572-4cda-9e2f-78de74d160a6

# %%
# Renombramos la columnas según nuestro modelo para cargarlos en la Base de Datos
df_cliente = df_cliente.rename(columns={ 'NOMCLI': 'nombre_cliente', 'EDAD_calculada': 'edad', 'SEX': 'genero', 'uuid': 'uuid_cliente' })
df_cliente.head()
# Out:
#   nombre_cliente  edad     genero                          uuid_cliente
# 0  Aaron Bergman    50  Masculino  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f
# 1  Aaron Bergman    50  Masculino  031fe653-fed6-4f09-803c-82f7e5290e5b
# 2  Aaron Bergman    50  Masculino  c43e77ce-628b-43eb-9fac-75f24dd1e661
# 3  Aaron Bergman    50  Masculino  88991106-d43a-4ca0-9f54-d0d64e66762e
# 4  Aaron Bergman    50  Masculino  9d7bbd67-9572-4cda-9e2f-78de74d160a6

# %%
# Funcion que inserta los registros en tabla
def _ingest_df_to_table(table_name, df):
    try:
        df.to_sql(name=table_name, if_exists="append", con=engine, index=False)
    except Exception as err:
        logging.error(f"Error { err }")
    return

# %%
df_pedido = df_copy[['ESTADO', 'REGION', 'CATE', 'CANT','DSCTO']]
df_pedido['uuid'] = [uuid.uuid4() for _ in range(len(df_pedido.index))]
df_pedido = df_pedido.rename(columns={ 'ESTADO':'estado', 'REGION': 'region', 'CATE': 'categoria', 'uuid': 'uuid_pedido', 'CANT': 'cantidad', 'DSCTO': 'descuento' })
df_pedido.head()
# Out:
# /tmp/ipykernel_865/2695811478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pedido['uuid'] = [uuid.uuid4() for _ in range(len(df_pedido.index))]
#       estado   region            categoria  cantidad  descuento  \
# 0  Entregado  America  Material de oficina       3.0        0.1
# 1  Entregado  America           Mobiliario       8.0        0.1
# 2  Entregado  America           Mobiliario       2.0        0.1
# 3  Entregado  America  Material de oficina       4.0        0.1
# 4  Entregado  America  Material de oficina       2.0        0.1
#
#                             uuid_pedido
# 0  31366edc-d9a2-4edb-b308-864507489ff0
# 1  a3676d93-79f2-487d-a948-27c4b3b64c09
# 2  cefca3be-b6e5-4439-86e4-95e03633d3f8
# 3  22119554-f16c-457f-8340-4ced1804e9f1
# 4  28d8b867-cb1f-481a-b11a-0f4e48c2f1e6

# %%
df_copy.columns
# Out:
# Index(['ID', 'FECPEDIDO', 'FECPRIME', 'FECVTO', 'FECMORA', 'ANIO', 'MES',
#        'DIA', 'MESNOMBRE', 'TRIMESTRE', 'SEMESTRE', 'NOMCLI', 'SEX', 'EDAD',
#        'EMAIL', 'REGION', 'CATE', 'NOMPRO', 'PRECIO', 'CANT', 'SUBTO', 'DSCTO',
#        'IGV', 'COST', 'TOTVTA', 'ESTADO', 'EDAD_new', 'ANIO_min', 'DIFF_ANIO',
#        'EDAD_calculada'],
#       dtype='object')

# %%
df_producto = df_copy[['NOMPRO', 'PRECIO', 'IGV']]
df_producto['uuid'] = [uuid.uuid4() for _ in range(len(df_producto.index))]
# Out:
# /tmp/ipykernel_865/1330088700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_producto['uuid'] = [uuid.uuid4() for _ in range(len(df_producto.index))]

# %%
df_producto = df_producto.rename(columns={ 'NOMPRO': 'nombre_producto', 'PRECIO': 'precio', 'IGV':'igv', 'uuid': 'uuid_producto' })
df_producto.head()
# Out:
#                       nombre_producto  precio    igv  \
# 0  Hon File Folder Labels, Adjustable    4.36   2.35
# 1                Tenex Clock, Durable   31.52  45.39
# 2        Ikea 3-Shelf Cabinet, Mobile   96.64  34.79
# 3              Cardinal Binder, Clear    8.86   6.38
# 4         Sanford Canvas, Water Color   35.80  12.89
#
#                           uuid_producto
# 0  a3a60288-3842-4bd2-b9dc-b5f66234471a
# 1  92ed6f35-7bcc-48df-a14f-0cf891a1284b
# 2  ad08f6d5-ac3c-4a95-bf5e-da2380543fa5
# 3  885a9e76-8db3-4a2f-96b5-e98cda50328b
# 4  d131b0c7-7c23-4cd7-803d-1eddb987f519

# %%
df_fecha = df_copy[['FECPEDIDO', 'FECPRIME', 'FECVTO', 'FECMORA', 'ANIO', 'MES', 'DIA', 'MESNOMBRE', 'TRIMESTRE', 'SEMESTRE']]
df_fecha['uuid'] = [uuid.uuid4() for _ in range(len(df_fecha.index))]
df_fecha = df_fecha.rename(columns={'FECPEDIDO': 'fec_pedido', 'FECPRIME': 'fec_prime', 'FECVTO': 'fec_vto', 'FECMORA': 'fec_mora', 'ANIO': 'anio', 'MES':'mes', 'DIA': 'dia', 'MESNOMBRE': 'mes_nombre', 'TRIMESTRE': 'trimestre', 'SEMESTRE': 'semestre', 'uuid': 'uuid_fecha'})
# Out:
# /tmp/ipykernel_865/1538072674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fecha['uuid'] = [uuid.uuid4() for _ in range(len(df_fecha.index))]

# %%
# Generar el df del sistema de ventas , tabla de hechos
rows, _ = df_copy.shape
df_sistema_ventas = pd.concat([df_cliente['uuid_cliente'], df_pedido['uuid_pedido'], df_fecha['uuid_fecha'], df_producto['uuid_producto']],axis=1,sort=False)
df_sistema_ventas.head()
# Out:
#                            uuid_cliente                           uuid_pedido  \
# 0  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f  31366edc-d9a2-4edb-b308-864507489ff0
# 1  031fe653-fed6-4f09-803c-82f7e5290e5b  a3676d93-79f2-487d-a948-27c4b3b64c09
# 2  c43e77ce-628b-43eb-9fac-75f24dd1e661  cefca3be-b6e5-4439-86e4-95e03633d3f8
# 3  88991106-d43a-4ca0-9f54-d0d64e66762e  22119554-f16c-457f-8340-4ced1804e9f1
# 4  9d7bbd67-9572-4cda-9e2f-78de74d160a6  28d8b867-cb1f-481a-b11a-0f4e48c2f1e6
#
#                              uuid_fecha                         uuid_producto
# 0  0ecbc46d-eb73-4921-8c21-99b112e518c3  a3a60288-3842-4bd2-b9dc-b5f66234471a
# 1  61523190-9ba9-4cce-86e9-a241dc64fd39  92ed6f35-7bcc-48df-a14f-0cf891a1284b
# 2  29e74903-ec56-4618-89d7-d5ec4f4035aa  ad08f6d5-ac3c-4a95-bf5e-da2380543fa5
# 3  55039121-f7d7-4ab8-9728-e5885f73350d  885a9e76-8db3-4a2f-96b5-e98cda50328b
# 4  eac07e2e-67b1-4187-86e9-f06de44fe03e  d131b0c7-7c23-4cd7-803d-1eddb987f519

# %%
# Renombrando los campos para poblar la tabla
df_sistema_ventas = df_sistema_ventas.rename(columns={ 'uuid_cliente': 'cliente_id_cliente', 'uuid_pedido': 'pedido_id_pedido', 'uuid_fecha':'fecha_id_fecha', 'uuid_producto': 'producto_id_producto' })
df_sistema_ventas.head()
# Out:
#                      cliente_id_cliente                      pedido_id_pedido  \
# 0  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f  31366edc-d9a2-4edb-b308-864507489ff0
# 1  031fe653-fed6-4f09-803c-82f7e5290e5b  a3676d93-79f2-487d-a948-27c4b3b64c09
# 2  c43e77ce-628b-43eb-9fac-75f24dd1e661  cefca3be-b6e5-4439-86e4-95e03633d3f8
# 3  88991106-d43a-4ca0-9f54-d0d64e66762e  22119554-f16c-457f-8340-4ced1804e9f1
# 4  9d7bbd67-9572-4cda-9e2f-78de74d160a6  28d8b867-cb1f-481a-b11a-0f4e48c2f1e6
#
#                          fecha_id_fecha                  producto_id_producto
# 0  0ecbc46d-eb73-4921-8c21-99b112e518c3  a3a60288-3842-4bd2-b9dc-b5f66234471a
# 1  61523190-9ba9-4cce-86e9-a241dc64fd39  92ed6f35-7bcc-48df-a14f-0cf891a1284b
# 2  29e74903-ec56-4618-89d7-d5ec4f4035aa  ad08f6d5-ac3c-4a95-bf5e-da2380543fa5
# 3  55039121-f7d7-4ab8-9728-e5885f73350d  885a9e76-8db3-4a2f-96b5-e98cda50328b
# 4  eac07e2e-67b1-4187-86e9-f06de44fe03e  d131b0c7-7c23-4cd7-803d-1eddb987f519

# %%
# Dataframe de clientes
df_cliente.head()
# Out:
#   nombre_cliente  edad     genero                          uuid_cliente
# 0  Aaron Bergman    50  Masculino  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f
# 1  Aaron Bergman    50  Masculino  031fe653-fed6-4f09-803c-82f7e5290e5b
# 2  Aaron Bergman    50  Masculino  c43e77ce-628b-43eb-9fac-75f24dd1e661
# 3  Aaron Bergman    50  Masculino  88991106-d43a-4ca0-9f54-d0d64e66762e
# 4  Aaron Bergman    50  Masculino  9d7bbd67-9572-4cda-9e2f-78de74d160a6

# %%
# Dataframe Pedidos
df_pedido.head()
# Out:
#       estado   region            categoria  cantidad  descuento  \
# 0  Entregado  America  Material de oficina       3.0        0.1
# 1  Entregado  America           Mobiliario       8.0        0.1
# 2  Entregado  America           Mobiliario       2.0        0.1
# 3  Entregado  America  Material de oficina       4.0        0.1
# 4  Entregado  America  Material de oficina       2.0        0.1
#
#                             uuid_pedido
# 0  31366edc-d9a2-4edb-b308-864507489ff0
# 1  a3676d93-79f2-487d-a948-27c4b3b64c09
# 2  cefca3be-b6e5-4439-86e4-95e03633d3f8
# 3  22119554-f16c-457f-8340-4ced1804e9f1
# 4  28d8b867-cb1f-481a-b11a-0f4e48c2f1e6

# %%
# Dataframa producto
df_producto.head()
# Out:
#                       nombre_producto  precio    igv  \
# 0  Hon File Folder Labels, Adjustable    4.36   2.35
# 1                Tenex Clock, Durable   31.52  45.39
# 2        Ikea 3-Shelf Cabinet, Mobile   96.64  34.79
# 3              Cardinal Binder, Clear    8.86   6.38
# 4         Sanford Canvas, Water Color   35.80  12.89
#
#                           uuid_producto
# 0  a3a60288-3842-4bd2-b9dc-b5f66234471a
# 1  92ed6f35-7bcc-48df-a14f-0cf891a1284b
# 2  ad08f6d5-ac3c-4a95-bf5e-da2380543fa5
# 3  885a9e76-8db3-4a2f-96b5-e98cda50328b
# 4  d131b0c7-7c23-4cd7-803d-1eddb987f519

# %%
# Dataframa fecha
df_fecha.head()
# Out:
#   fec_pedido  fec_prime    fec_vto   fec_mora  anio  mes  dia mes_nombre  \
# 0 2017-01-01 2013-01-06 2017-01-11 2017-01-12  2017    1    1      Enero
# 1 2017-02-12 2013-01-06 2017-02-22 2017-02-23  2017    2   12    Febrero
# 2 2017-03-10 2013-01-06 2017-03-20 2017-03-21  2017    3   10      Marzo
# 3 2017-04-10 2013-01-06 2017-04-20 2017-04-21  2017    4   10      Abril
# 4 2017-05-06 2013-01-06 2017-05-16 2017-05-17  2017    5    6       Mayo
#
#    trimestre  semestre                            uuid_fecha
# 0          1         1  0ecbc46d-eb73-4921-8c21-99b112e518c3
# 1          1         1  61523190-9ba9-4cce-86e9-a241dc64fd39
# 2          1         1  29e74903-ec56-4618-89d7-d5ec4f4035aa
# 3          2         1  55039121-f7d7-4ab8-9728-e5885f73350d
# 4          2         1  eac07e2e-67b1-4187-86e9-f06de44fe03e

# %%
# Dataframa sistema ventas
df_sistema_ventas.head()
# Out:
#                      cliente_id_cliente                      pedido_id_pedido  \
# 0  d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f  31366edc-d9a2-4edb-b308-864507489ff0
# 1  031fe653-fed6-4f09-803c-82f7e5290e5b  a3676d93-79f2-487d-a948-27c4b3b64c09
# 2  c43e77ce-628b-43eb-9fac-75f24dd1e661  cefca3be-b6e5-4439-86e4-95e03633d3f8
# 3  88991106-d43a-4ca0-9f54-d0d64e66762e  22119554-f16c-457f-8340-4ced1804e9f1
# 4  9d7bbd67-9572-4cda-9e2f-78de74d160a6  28d8b867-cb1f-481a-b11a-0f4e48c2f1e6
#
#                          fecha_id_fecha                  producto_id_producto
# 0  0ecbc46d-eb73-4921-8c21-99b112e518c3  a3a60288-3842-4bd2-b9dc-b5f66234471a
# 1  61523190-9ba9-4cce-86e9-a241dc64fd39  92ed6f35-7bcc-48df-a14f-0cf891a1284b
# 2  29e74903-ec56-4618-89d7-d5ec4f4035aa  ad08f6d5-ac3c-4a95-bf5e-da2380543fa5
# 3  55039121-f7d7-4ab8-9728-e5885f73350d  885a9e76-8db3-4a2f-96b5-e98cda50328b
# 4  eac07e2e-67b1-4187-86e9-f06de44fe03e  d131b0c7-7c23-4cd7-803d-1eddb987f519

# %% [markdown]
# ### Script para poblar base de datos transaccional

# %%
# Poblar datos de clientes
_ingest_df_to_table("cliente", df_cliente)
# Out:
# 2024-06-30 22:56:28,826 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 22:56:28,829 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`cliente`
# 2024-06-30 22:56:28,830 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 22:56:28,833 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 22:56:28,833 DEBUG sqlalchemy.engine.Engine Row ('id_cliente', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 22:56:28,874 INFO sqlalchemy.engine.Engine INSERT INTO cliente (nombre_cliente, edad, genero, uuid_cliente) VALUES (%(nombre_cliente)s, %(edad)s, %(genero)s, %(uuid_cliente)s)
# 2024-06-30 22:56:28,875 INFO sqlalchemy.engine.Engine [generated in 0.02996s] [{'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('031fe653-fed6-4f09-803c-82f7e5290e5b')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('c43e77ce-628b-43eb-9fac-75f24dd1e661')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('88991106-d43a-4ca0-9f54-d0d64e66762e')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('9d7bbd67-9572-4cda-9e2f-78de74d160a6')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('0eee6c79-01ae-4555-afd2-44da48ecd763')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('48c48875-8a79-4cc4-92e0-6de1b9c2f06d')}, {'nombre_cliente': 'Aaron Bergman', 'edad': 50, 'genero': 'Masculino', 'uuid_cliente': UUID('29b8cb8f-ff6f-4ba6-8f75-f3c5962767dd')}  ... displaying 10 of 14752 total bound parameter sets ...  {'nombre_cliente': 'Valerie Dominguez', 'edad': 43, 'genero': 'Femenino', 'uuid_cliente': UUID('a2d76bbc-3c4a-46bc-a232-3698a507278d')}, {'nombre_cliente': 'Valerie Dominguez', 'edad': 43, 'genero': 'Femenino', 'uuid_cliente': UUID('1868e266-172e-469b-ab1c-972078ee7140')}]
# 2024-06-30 22:56:31,010 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Poblar la tabla pedidos
_ingest_df_to_table("pedido", df_pedido)
# Out:
# 2024-06-30 23:05:36,905 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 23:05:36,909 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`pedido`
# 2024-06-30 23:05:36,909 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 23:05:36,912 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 23:05:36,912 DEBUG sqlalchemy.engine.Engine Row ('id_pedido', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 23:05:37,071 INFO sqlalchemy.engine.Engine INSERT INTO pedido (estado, region, categoria, cantidad, descuento, uuid_pedido) VALUES (%(estado)s, %(region)s, %(categoria)s, %(cantidad)s, %(descuento)s, %(uuid_pedido)s)
# 2024-06-30 23:05:37,071 INFO sqlalchemy.engine.Engine [generated in 0.14386s] [{'estado': 'Entregado', 'region': 'America', 'categoria': 'Material de oficina', 'cantidad': 3.0, 'descuento': 0.1, 'uuid_pedido': UUID('31366edc-d9a2-4edb-b308-864507489ff0')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Mobiliario', 'cantidad': 8.0, 'descuento': 0.1, 'uuid_pedido': UUID('a3676d93-79f2-487d-a948-27c4b3b64c09')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Mobiliario', 'cantidad': 2.0, 'descuento': 0.1, 'uuid_pedido': UUID('cefca3be-b6e5-4439-86e4-95e03633d3f8')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Material de oficina', 'cantidad': 4.0, 'descuento': 0.1, 'uuid_pedido': UUID('22119554-f16c-457f-8340-4ced1804e9f1')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Material de oficina', 'cantidad': 2.0, 'descuento': 0.1, 'uuid_pedido': UUID('28d8b867-cb1f-481a-b11a-0f4e48c2f1e6')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Material de oficina', 'cantidad': 2.0, 'descuento': 0.1, 'uuid_pedido': UUID('d16ffe7a-89cc-4792-83bd-b74774b8747d')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Material de oficina', 'cantidad': 3.0, 'descuento': 0.1, 'uuid_pedido': UUID('c4680872-cec9-4951-b87a-cd6a0968b664')}, {'estado': 'Entregado', 'region': 'America', 'categoria': 'Mobiliario', 'cantidad': 4.0, 'descuento': 0.1, 'uuid_pedido': UUID('1b8f2cbf-d67d-435f-8419-0223981ea0ca')}  ... displaying 10 of 14752 total bound parameter sets ...  {'estado': 'Anulado', 'region': 'Asia', 'categoria': 'Material de oficina', 'cantidad': 1.0, 'descuento': 0.1, 'uuid_pedido': UUID('80555e15-031d-4b6b-b935-ee6f72771ca1')}, {'estado': 'Entregado', 'region': 'Oceanía', 'categoria': 'Material de oficina', 'cantidad': 4.0, 'descuento': 0.1, 'uuid_pedido': UUID('70113d26-cc2f-4ecd-9968-c76749728456')}]
# 2024-06-30 23:05:39,108 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Poblar la tabla productos
_ingest_df_to_table("producto", df_producto)
# Out:
# 2024-06-30 23:05:42,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 23:05:42,190 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`producto`
# 2024-06-30 23:05:42,190 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 23:05:42,193 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 23:05:42,193 DEBUG sqlalchemy.engine.Engine Row ('id_producto', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 23:05:42,240 INFO sqlalchemy.engine.Engine INSERT INTO producto (nombre_producto, precio, igv, uuid_producto) VALUES (%(nombre_producto)s, %(precio)s, %(igv)s, %(uuid_producto)s)
# 2024-06-30 23:05:42,241 INFO sqlalchemy.engine.Engine [generated in 0.03143s] [{'nombre_producto': 'Hon File Folder Labels, Adjustable', 'precio': 4.36, 'igv': 2.35, 'uuid_producto': UUID('a3a60288-3842-4bd2-b9dc-b5f66234471a')}, {'nombre_producto': 'Tenex Clock, Durable', 'precio': 31.52, 'igv': 45.39, 'uuid_producto': UUID('92ed6f35-7bcc-48df-a14f-0cf891a1284b')}, {'nombre_producto': 'Ikea 3-Shelf Cabinet, Mobile', 'precio': 96.64, 'igv': 34.79, 'uuid_producto': UUID('ad08f6d5-ac3c-4a95-bf5e-da2380543fa5')}, {'nombre_producto': 'Cardinal Binder, Clear', 'precio': 8.86, 'igv': 6.38, 'uuid_producto': UUID('885a9e76-8db3-4a2f-96b5-e98cda50328b')}, {'nombre_producto': 'Sanford Canvas, Water Color', 'precio': 35.8, 'igv': 12.89, 'uuid_producto': UUID('d131b0c7-7c23-4cd7-803d-1eddb987f519')}, {'nombre_producto': 'GlobeWeis Mailers, with clear poly window', 'precio': 28.06, 'igv': 10.1, 'uuid_producto': UUID('8305f67d-df34-4d7b-8ff0-0edf6d26afeb')}, {'nombre_producto': 'Accos Staples, 12 Pack', 'precio': 6.92, 'igv': 3.74, 'uuid_producto': UUID('b0076493-721e-4564-b206-b41b8e628920')}, {'nombre_producto': 'Hon Steel Folding Chair, Black', 'precio': 52.66, 'igv': 37.92, 'uuid_producto': UUID('606a9f7e-c945-494d-a473-c61c5eed199f')}  ... displaying 10 of 14752 total bound parameter sets ...  {'nombre_producto': 'Binney & Smith Highlighters, Easy-Erase', 'precio': 5.06, 'igv': 0.91, 'uuid_producto': UUID('bb0545b5-81f8-450b-82bd-52c7323ee5e9')}, {'nombre_producto': 'Binney & Smith Sketch Pad, Blue', 'precio': 46.32, 'igv': 33.35, 'uuid_producto': UUID('a2a59ed5-60dd-45b8-a0a3-26f7b9094d2b')}]
# 2024-06-30 23:05:43,965 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Poblar la tabla fechas
_ingest_df_to_table('fecha', df_fecha)
# Out:
# 2024-06-30 23:05:54,315 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 23:05:54,319 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`fecha`
# 2024-06-30 23:05:54,320 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 23:05:54,322 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 23:05:54,323 DEBUG sqlalchemy.engine.Engine Row ('id_fecha', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 23:05:54,512 INFO sqlalchemy.engine.Engine INSERT INTO fecha (fec_pedido, fec_prime, fec_vto, fec_mora, anio, mes, dia, mes_nombre, trimestre, semestre, uuid_fecha) VALUES (%(fec_pedido)s, %(fec_prime)s, %(fec_vto)s, %(fec_mora)s, %(anio)s, %(mes)s, %(dia)s, %(mes_nombre)s, %(trimestre)s, %(semestre)s, %(uuid_fecha)s)
# 2024-06-30 23:05:54,513 INFO sqlalchemy.engine.Engine [generated in 0.14071s] [{'fec_pedido': datetime.datetime(2017, 1, 1, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 1, 11, 0, 0), 'fec_mora': datetime.datetime(2017, 1, 12, 0, 0), 'anio': 2017, 'mes': 1, 'dia': 1, 'mes_nombre': 'Enero', 'trimestre': 1, 'semestre': 1, 'uuid_fecha': UUID('0ecbc46d-eb73-4921-8c21-99b112e518c3')}, {'fec_pedido': datetime.datetime(2017, 2, 12, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 2, 22, 0, 0), 'fec_mora': datetime.datetime(2017, 2, 23, 0, 0), 'anio': 2017, 'mes': 2, 'dia': 12, 'mes_nombre': 'Febrero', 'trimestre': 1, 'semestre': 1, 'uuid_fecha': UUID('61523190-9ba9-4cce-86e9-a241dc64fd39')}, {'fec_pedido': datetime.datetime(2017, 3, 10, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 3, 20, 0, 0), 'fec_mora': datetime.datetime(2017, 3, 21, 0, 0), 'anio': 2017, 'mes': 3, 'dia': 10, 'mes_nombre': 'Marzo', 'trimestre': 1, 'semestre': 1, 'uuid_fecha': UUID('29e74903-ec56-4618-89d7-d5ec4f4035aa')}, {'fec_pedido': datetime.datetime(2017, 4, 10, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 4, 20, 0, 0), 'fec_mora': datetime.datetime(2017, 4, 21, 0, 0), 'anio': 2017, 'mes': 4, 'dia': 10, 'mes_nombre': 'Abril', 'trimestre': 2, 'semestre': 1, 'uuid_fecha': UUID('55039121-f7d7-4ab8-9728-e5885f73350d')}, {'fec_pedido': datetime.datetime(2017, 5, 6, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 5, 16, 0, 0), 'fec_mora': datetime.datetime(2017, 5, 17, 0, 0), 'anio': 2017, 'mes': 5, 'dia': 6, 'mes_nombre': 'Mayo', 'trimestre': 2, 'semestre': 1, 'uuid_fecha': UUID('eac07e2e-67b1-4187-86e9-f06de44fe03e')}, {'fec_pedido': datetime.datetime(2017, 6, 5, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 6, 15, 0, 0), 'fec_mora': datetime.datetime(2017, 6, 16, 0, 0), 'anio': 2017, 'mes': 6, 'dia': 5, 'mes_nombre': 'Junio', 'trimestre': 2, 'semestre': 1, 'uuid_fecha': UUID('62e58d1f-3144-4992-83d5-38563b78a92a')}, {'fec_pedido': datetime.datetime(2017, 7, 25, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 8, 4, 0, 0), 'fec_mora': datetime.datetime(2017, 8, 5, 0, 0), 'anio': 2017, 'mes': 7, 'dia': 25, 'mes_nombre': 'Julio', 'trimestre': 3, 'semestre': 2, 'uuid_fecha': UUID('dd4e917b-486f-4376-adc5-65e56f32cb3e')}, {'fec_pedido': datetime.datetime(2017, 8, 12, 0, 0), 'fec_prime': datetime.datetime(2013, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 8, 22, 0, 0), 'fec_mora': datetime.datetime(2017, 8, 23, 0, 0), 'anio': 2017, 'mes': 8, 'dia': 12, 'mes_nombre': 'Agosto', 'trimestre': 3, 'semestre': 2, 'uuid_fecha': UUID('5f0088c3-3726-4a3d-bdd3-863547d127fe')}  ... displaying 10 of 14752 total bound parameter sets ...  {'fec_pedido': datetime.datetime(2017, 5, 23, 0, 0), 'fec_prime': datetime.datetime(2015, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 6, 2, 0, 0), 'fec_mora': datetime.datetime(2017, 6, 3, 0, 0), 'anio': 2017, 'mes': 5, 'dia': 23, 'mes_nombre': 'Mayo', 'trimestre': 2, 'semestre': 1, 'uuid_fecha': UUID('47732b2f-9134-465c-ae7e-193b7c7e4189')}, {'fec_pedido': datetime.datetime(2017, 6, 30, 0, 0), 'fec_prime': datetime.datetime(2015, 1, 6, 0, 0), 'fec_vto': datetime.datetime(2017, 7, 10, 0, 0), 'fec_mora': datetime.datetime(2017, 7, 11, 0, 0), 'anio': 2017, 'mes': 6, 'dia': 30, 'mes_nombre': 'Junio', 'trimestre': 2, 'semestre': 1, 'uuid_fecha': UUID('eaccee1a-8f29-404a-b99f-b3ebbc2a11cd')}]
# 2024-06-30 23:05:56,706 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Poblar la base de datos sistema de ventas
_ingest_df_to_table('sistema_ventas', df_sistema_ventas)
# Out:
# 2024-06-30 23:06:00,733 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 23:06:00,736 INFO sqlalchemy.engine.Engine DESCRIBE `datapath`.`sistema_ventas`
# 2024-06-30 23:06:00,736 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-06-30 23:06:00,740 DEBUG sqlalchemy.engine.Engine Col ('Field', 'Type', 'Null', 'Key', 'Default', 'Extra')
# 2024-06-30 23:06:00,740 DEBUG sqlalchemy.engine.Engine Row ('id_venta', 'int', 'NO', 'PRI', None, 'auto_increment')
# 2024-06-30 23:06:00,810 INFO sqlalchemy.engine.Engine INSERT INTO sistema_ventas (cliente_id_cliente, pedido_id_pedido, fecha_id_fecha, producto_id_producto) VALUES (%(cliente_id_cliente)s, %(pedido_id_pedido)s, %(fecha_id_fecha)s, %(producto_id_producto)s)
# 2024-06-30 23:06:00,815 INFO sqlalchemy.engine.Engine [generated in 0.06073s] [{'cliente_id_cliente': UUID('d7f6ae0d-58ed-4ecd-a5be-d28b23b2e87f'), 'pedido_id_pedido': UUID('31366edc-d9a2-4edb-b308-864507489ff0'), 'fecha_id_fecha': UUID('0ecbc46d-eb73-4921-8c21-99b112e518c3'), 'producto_id_producto': UUID('a3a60288-3842-4bd2-b9dc-b5f66234471a')}, {'cliente_id_cliente': UUID('031fe653-fed6-4f09-803c-82f7e5290e5b'), 'pedido_id_pedido': UUID('a3676d93-79f2-487d-a948-27c4b3b64c09'), 'fecha_id_fecha': UUID('61523190-9ba9-4cce-86e9-a241dc64fd39'), 'producto_id_producto': UUID('92ed6f35-7bcc-48df-a14f-0cf891a1284b')}, {'cliente_id_cliente': UUID('c43e77ce-628b-43eb-9fac-75f24dd1e661'), 'pedido_id_pedido': UUID('cefca3be-b6e5-4439-86e4-95e03633d3f8'), 'fecha_id_fecha': UUID('29e74903-ec56-4618-89d7-d5ec4f4035aa'), 'producto_id_producto': UUID('ad08f6d5-ac3c-4a95-bf5e-da2380543fa5')}, {'cliente_id_cliente': UUID('88991106-d43a-4ca0-9f54-d0d64e66762e'), 'pedido_id_pedido': UUID('22119554-f16c-457f-8340-4ced1804e9f1'), 'fecha_id_fecha': UUID('55039121-f7d7-4ab8-9728-e5885f73350d'), 'producto_id_producto': UUID('885a9e76-8db3-4a2f-96b5-e98cda50328b')}, {'cliente_id_cliente': UUID('9d7bbd67-9572-4cda-9e2f-78de74d160a6'), 'pedido_id_pedido': UUID('28d8b867-cb1f-481a-b11a-0f4e48c2f1e6'), 'fecha_id_fecha': UUID('eac07e2e-67b1-4187-86e9-f06de44fe03e'), 'producto_id_producto': UUID('d131b0c7-7c23-4cd7-803d-1eddb987f519')}, {'cliente_id_cliente': UUID('0eee6c79-01ae-4555-afd2-44da48ecd763'), 'pedido_id_pedido': UUID('d16ffe7a-89cc-4792-83bd-b74774b8747d'), 'fecha_id_fecha': UUID('62e58d1f-3144-4992-83d5-38563b78a92a'), 'producto_id_producto': UUID('8305f67d-df34-4d7b-8ff0-0edf6d26afeb')}, {'cliente_id_cliente': UUID('48c48875-8a79-4cc4-92e0-6de1b9c2f06d'), 'pedido_id_pedido': UUID('c4680872-cec9-4951-b87a-cd6a0968b664'), 'fecha_id_fecha': UUID('dd4e917b-486f-4376-adc5-65e56f32cb3e'), 'producto_id_producto': UUID('b0076493-721e-4564-b206-b41b8e628920')}, {'cliente_id_cliente': UUID('29b8cb8f-ff6f-4ba6-8f75-f3c5962767dd'), 'pedido_id_pedido': UUID('1b8f2cbf-d67d-435f-8419-0223981ea0ca'), 'fecha_id_fecha': UUID('5f0088c3-3726-4a3d-bdd3-863547d127fe'), 'producto_id_producto': UUID('606a9f7e-c945-494d-a473-c61c5eed199f')}  ... displaying 10 of 14752 total bound parameter sets ...  {'cliente_id_cliente': UUID('a2d76bbc-3c4a-46bc-a232-3698a507278d'), 'pedido_id_pedido': UUID('80555e15-031d-4b6b-b935-ee6f72771ca1'), 'fecha_id_fecha': UUID('47732b2f-9134-465c-ae7e-193b7c7e4189'), 'producto_id_producto': UUID('bb0545b5-81f8-450b-82bd-52c7323ee5e9')}, {'cliente_id_cliente': UUID('1868e266-172e-469b-ab1c-972078ee7140'), 'pedido_id_pedido': UUID('70113d26-cc2f-4ecd-9968-c76749728456'), 'fecha_id_fecha': UUID('eaccee1a-8f29-404a-b99f-b3ebbc2a11cd'), 'producto_id_producto': UUID('a2a59ed5-60dd-45b8-a0a3-26f7b9094d2b')}]
# 2024-06-30 23:06:03,183 INFO sqlalchemy.engine.Engine COMMIT
